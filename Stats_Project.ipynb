# %% [markdown]
# <a href="https://colab.research.google.com/github/Code0710/Ds/blob/main/Stats_Project.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
from scipy.stats import f_oneway
import matplotlib.pyplot as plt

# Load iris.csv dataset
iris = pd.read_csv("iris.csv")
print(iris.columns)

# Split dataset by species
setosa = iris[iris["variety"] == "setosa"]["petal.length"]
versicolor = iris[iris["variety"] == "versicolor"]["petal.length"]
virginica = iris[iris["variety"] == "virginica"]["petal.length"]

# Perform one-way ANOVA test
f_stat, p_value = f_oneway(setosa, versicolor, virginica)

# Print results
print("F-statistic:", f_stat)
print("P-value:", p_value)

# Visualize boxplots of each species
fig, ax = plt.subplots()
ax.boxplot([setosa, versicolor, virginica])
ax.set_xticklabels(["Setosa", "Versicolor", "Virginica"])
ax.set_ylabel("sepal Length (cm)")
ax.set_title("Comparison of sepal Length by Iris variety")
plt.show()
# Out:
# Index(['sepal.length', 'sepal.width', 'petal.length', 'petal.width',
#        'variety'],
#       dtype='object')
# F-statistic: nan
# P-value: nan
# /usr/local/lib/python3.9/dist-packages/scipy/stats/_stats_py.py:3861: DegenerateDataWarning:
#
# at least one input has length 0

# %%
import pandas as pd
import plotly.express as px

# Load iris.csv dataset
iris = pd.read_csv("iris.csv")

# Create scatter plot of petal length vs. petal width, colored by species
fig = px.scatter(iris, x="petal.length", y="petal.width", color="variety",
                 title="Iris Dataset", labels={"petal.length": "Petal Length (cm)",
                                                "petal.width": "Petal Width (cm)"})

# Show plot
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
import pandas as pd
import matplotlib.pyplot as plt
from scipy.stats import f_oneway

# Load iris.csv dataset
iris = pd.read_csv("iris.csv")

# Split dataset by species
setosa = iris[iris["variety"] == "setosa"]["petal.length"]
versicolor = iris[iris["variety"] == "versicolor"]["petal.length"]
virginica = iris[iris["variety"] == "virginica"]["petal.length"]

# Perform one-way ANOVA test
f_stat, p_value = f_oneway(setosa, versicolor, virginica)

# Print results
print("F-value:", f_stat)
print("P-value:", p_value)

# Create box plot of petal length by species
data = [setosa, versicolor, virginica]
fig, ax = plt.subplots()
ax.boxplot(data)
ax.set_xticklabels(["Setosa", "Versicolor", "Virginica"])
ax.set_ylabel("Petal Length (cm)")
ax.set_title("Petal Length by variety")

# Show plot
plt.show()
# Out:
# F-value: nan
# P-value: nan
# /usr/local/lib/python3.9/dist-packages/scipy/stats/_stats_py.py:3861: DegenerateDataWarning:
#
# at least one input has length 0

# %%
import pandas as pd
import seaborn as sns
from scipy.stats import f_oneway

# Load iris.csv dataset
iris = pd.read_csv("iris.csv")

# Split dataset by species and replace NaN values with 0
setosa = iris[iris["variety"] == "setosa"]["petal.length"].fillna(0)
versicolor = iris[iris["variety"] == "versicolor"]["petal.length"].fillna(0)
virginica = iris[iris["variety"] == "virginica"]["petal.length"].fillna(0)

# Perform one-way ANOVA test
f_stat, p_value = f_oneway(setosa, versicolor, virginica)

# Print results
print("F-value:", f_stat)
print("P-value:", p_value)

# Visualize results using box plot
sns.boxplot(data=iris, x="variety", y="petal.length")
# Out:
# F-value: nan
# P-value: nan
# /usr/local/lib/python3.9/dist-packages/scipy/stats/_stats_py.py:3861: DegenerateDataWarning: at least one input has length 0
#   warnings.warn(stats.DegenerateDataWarning('at least one input '
# <AxesSubplot:xlabel='variety', ylabel='petal.length'>

# %%
import pandas as pd
import seaborn as sns
from scipy.stats import f_oneway

# Load iris.csv dataset
iris = pd.read_csv("iris.csv")

# Split dataset by species and replace NaN values with 0
setosa = iris[iris["variety"] == "setosa"]["petal.length"].fillna(0)
versicolor = iris[iris["variety"] == "versicolor"]["petal.length"].fillna(0)
virginica = iris[iris["variety"] == "virginica"]["petal.length"].fillna(0)

# Calculate mean petal length for each species
setosa_mean = setosa.mean()
versicolor_mean = versicolor.mean()
virginica_mean = virginica.mean()

# Perform one-way ANOVA test
f_stat, p_value = f_oneway(setosa, versicolor, virginica)

# Print results
print("F-value:", f_stat)
print("P-value:", p_value)

# Create scatterplot to visualize distribution of petal lengths for each species
sns.heatmap(iris.corr(), annot=True, cmap="YlGnBu")
# Out:
# F-value: nan
# P-value: nan
# /usr/local/lib/python3.9/dist-packages/scipy/stats/_stats_py.py:3861: DegenerateDataWarning:
#
# at least one input has length 0
# <AxesSubplot:>

# %%
import pandas as pd
import seaborn as sns
from scipy.stats import f_oneway

# Load iris.csv dataset
iris = pd.read_csv("iris.csv")

# Split dataset by species and replace NaN values with 0
setosa = iris[iris["variety"] == "setosa"]["petal.length"].fillna(0)
versicolor = iris[iris["variety"] == "versicolor"]["petal.length"].fillna(0)
virginica = iris[iris["variety"] == "virginica"]["petal.length"].fillna(0)

# Calculate mean petal length for each species
setosa_mean = setosa.mean()
versicolor_mean = versicolor.mean()
virginica_mean = virginica.mean()

# Perform one-way ANOVA test
f_stat, p_value = f_oneway(setosa, versicolor, virginica)

# Print results
print("F-value:", f_stat)
print("P-value:", p_value)

# Visualize results using a heatmap
sns.heatmap(iris.corr(), annot=True, cmap="YlGnBu")
# Out:
# F-value: nan
# P-value: nan
# /usr/local/lib/python3.9/dist-packages/scipy/stats/_stats_py.py:3861: DegenerateDataWarning: at least one input has length 0
#   warnings.warn(stats.DegenerateDataWarning('at least one input '
# <AxesSubplot:>

# %%
import pandas as pd
import seaborn as sns
from scipy.stats import f_oneway
from statsmodels.formula.api import ols
from statsmodels.stats.anova import anova_lm

# Load iris.csv dataset
iris = pd.read_csv("iris.csv")

# Split dataset by species and replace NaN values with 0
setosa = iris[iris["variety"] == "Setosa"]["petal.length"].fillna(0)
versicolor = iris[iris["variety"] == "Versicolor"]["petal.length"].fillna(0)
virginica = iris[iris["variety"] == "Virginica"]["petal.length"].fillna(0)

# Define null and alternative hypotheses
null_hypothesis = "The mean petal length is equal across all three species of iris (setosa, versicolor, and virginica)."
alt_hypothesis = "The mean petal length differs across at least one of the three species of iris."

# Perform one-way ANOVA test
f_stat, p_value = f_oneway(setosa, versicolor, virginica)

# Print results
print("One-way ANOVA test:")
print("Null hypothesis:", null_hypothesis)
print("Alternative hypothesis:", alt_hypothesis)
print("F-value:", f_stat)
print("P-value:", p_value)

# Define significance level
alpha = 0.05

# Determine whether to accept or reject null hypothesis
if p_value < alpha:
    print("We reject the null hypothesis.")
else:
    print("We accept the null hypothesis.")

# Perform two-way ANOVA test
model = ols("petal.length + C(variety) + C(sepal.width) + C(variety):C(sepal.width)", data=iris).fit()
anova_table = anova_lm(model, typ=2)

# Print results
print("\nTwo-way ANOVA test:")
print(anova_table)

# Visualize results using a heatmap
sns.heatmap(iris.corr(), annot=True, cmap="YlGnBu")
# Out:
# One-way ANOVA test:
# Null hypothesis: The mean petal length is equal across all three species of iris (setosa, versicolor, and virginica).
# Alternative hypothesis: The mean petal length differs across at least one of the three species of iris.
# F-value: 1112.0337483371395
# P-value: 1.735586228597225e-89
# We reject the null hypothesis.
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /usr/local/lib/python3.9/dist-packages/patsy/compat.py in call_and_wrap_exc(msg, origin, f, *args, **kwargs)
#      35     try:
# ---> 36         return f(*args, **kwargs)
#      37     except Exception as e:
#
# /usr/local/lib/python3.9/dist-packages/patsy/eval.py in eval(self, expr, source_name, inner_namespace)
#     168         code = compile(expr, source_name, "eval", self.flags, False)
# --> 169         return eval(code, {}, VarLookupDict([inner_namespace]
# ...

# %%
import pandas as pd
import seaborn as sns
import statsmodels.api as sm
from statsmodels.formula.api import ols

# Load iris.csv dataset
iris = pd.read_csv("iris.csv")

# Replace NaN values with 0
iris = iris.fillna(0)

# Perform two-way ANOVA test
model = ols('petal.length ~ C(variety) + C(petal.width)', data=iris).fit()
anova_table = sm.stats.anova_lm(model, typ=2)

# Print results
print(anova_table)

# Visualize results using a heatmap
sns.heatmap(iris.corr(), annot=True, cmap="YlGnBu")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /usr/local/lib/python3.9/dist-packages/patsy/compat.py in call_and_wrap_exc(msg, origin, f, *args, **kwargs)
#      35     try:
# ---> 36         return f(*args, **kwargs)
#      37     except Exception as e:
#
# /usr/local/lib/python3.9/dist-packages/patsy/eval.py in eval(self, expr, source_name, inner_namespace)
#     168         code = compile(expr, source_name, "eval", self.flags, False)
# --> 169         return eval(code, {}, VarLookupDict([inner_namespace]
#     170                                             + self._namespaces))
#
# <string> in <module>
#
# NameError: name 'petal' is not defined
#
# The above exception was the direct cause of the following exception:
#
# PatsyError                                Traceback (most recent call last)
# <ipython-input-2-6076428ce57b> in <module>
#      11
# ...

# %%
import pandas as pd
import seaborn as sns
from scipy.stats import f_oneway
from statsmodels.formula.api import ols
from statsmodels.stats.anova import anova_lm

# Load iris.csv dataset
iris = pd.read_csv("iris.csv")

# Split dataset by species and replace NaN values with 0
setosa = iris[iris["variety"] == "Setosa"]["petal.length"].fillna(0)
versicolor = iris[iris["variety"] == "Versicolor"]["petal.length"].fillna(0)
virginica = iris[iris["variety"] == "Virginica"]["petal.length"].fillna(0)

# Define null and alternative hypotheses
null_hypothesis = "The mean petal length is equal across all three species of iris (setosa, versicolor, and virginica)."
alt_hypothesis = "The mean petal length differs across at least one of the three species of iris."

# Perform one-way ANOVA test
f_stat, p_value = f_oneway(setosa, versicolor, virginica)

# Print results
print("One-way ANOVA test:")
print("Null hypothesis:", null_hypothesis)
print("Alternative hypothesis:", alt_hypothesis)
print("F-value:", f_stat)
print("P-value:", p_value)

# Define significance level
alpha = 0.05

# Determine whether to accept or reject null hypothesis
if p_value < alpha:
    print("We reject the null hypothesis.")
else:
    print("We accept the null hypothesis.")

# Perform two-way ANOVA test
iris.columns = iris.columns.str.replace(".", "_")
model = ols("petal_length ~ C(variety) + C(sepal_width) + C(variety):C(sepal_width)", data=iris).fit()
anova_table = anova_lm(model, typ=2)

# Print results
print("\nTwo-way ANOVA test:")
print(anova_table)

# Visualize results using a heatmap
sns.heatmap(iris.corr(), annot=True, cmap="YlGnBu")
# Out:
# One-way ANOVA test:
# Null hypothesis: The mean petal length is equal across all three species of iris (setosa, versicolor, and virginica).
# Alternative hypothesis: The mean petal length differs across at least one of the three species of iris.
# F-value: 1112.0337483371395
# P-value: 1.735586228597225e-89
# We reject the null hypothesis.
#
# Two-way ANOVA test:
#                                sum_sq     df          F        PR(>F)
# C(variety)                        NaN    2.0        NaN           NaN
# C(sepal_width)              42.703250   22.0  11.768933  4.242924e-10
# C(variety):C(sepal_width)  656.707322   44.0  90.493630  3.801781e-61
# Residual                    17.647571  107.0        NaN           NaN
# <ipython-input-4-96fcc21dd25e>:39: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
# ...

# %%
import pandas as pd
import seaborn as sns
from scipy.stats import f_oneway
import urllib

# Load iris.csv dataset from Github
iris = sns.load_dataset("iris")

# Split dataset by species and replace NaN values with 0
setosa = iris[iris["species"] == "setosa"]["petal_length"].fillna(0)
versicolor = iris[iris["species"] == "versicolor"]["petal_length"].fillna(0)
virginica = iris[iris["species"] == "virginica"]["petal_length"].fillna(0)

# Define null and alternative hypotheses
null_hypothesis = "The mean petal length is equal across all three species of iris (setosa, versicolor, and virginica)."
alt_hypothesis = "The mean petal length differs across at least one of the three species of iris."

# Perform one-way ANOVA test
f_stat, p_value = f_oneway(setosa, versicolor, virginica)

# Print results
print("Null hypothesis:", null_hypothesis)
print("Alternative hypothesis:", alt_hypothesis)
print("F-value:", f_stat)
print("P-value:", p_value)

# Define significance level
alpha = 0.05

# Determine whether to accept or reject null hypothesis
if p_value < alpha:
    print("We reject the null hypothesis.")
else:
    print("We accept the null hypothesis.")
    
# Visualize results using a heatmap
sns.heatmap(iris.corr(), annot=True, cmap="YlGnBu")
# Out:
# Null hypothesis: The mean petal length is equal across all three species of iris (setosa, versicolor, and virginica).
# Alternative hypothesis: The mean petal length differs across at least one of the three species of iris.
# F-value: 1180.161182252981
# P-value: 2.8567766109615584e-91
# We reject the null hypothesis.
# <Axes: >

# %%
import pandas as pd
import seaborn as sns
from scipy.stats import f_oneway

# Load iris.csv dataset from Github
url = 'https://raw.githubusercontent.com/mwaskom/seaborn-data/master/iris.csv'
iris = pd.read_csv(url)

# Split dataset by species and replace NaN values with 0
setosa = iris[iris["species"] == "setosa"]["petal_length"].fillna(0)
versicolor = iris[iris["species"] == "versicolor"]["petal_length"].fillna(0)
virginica = iris[iris["species"] == "virginica"]["petal_length"].fillna(0)

# Define null and alternative hypotheses
null_hypothesis = "The mean petal length is equal across all three species of iris (setosa, versicolor, and virginica)."
alt_hypothesis = "The mean petal length differs across at least one of the three species of iris."

# Perform one-way ANOVA test
f_stat, p_value = f_oneway(setosa, versicolor, virginica)

# Print results
print("Null hypothesis:", null_hypothesis)
print("Alternative hypothesis:", alt_hypothesis)
print("F-value:", f_stat)
print("P-value:", p_value)

# Define significance level
alpha = 0.05

# Determine whether to accept or reject null hypothesis
if p_value < alpha:
    print("We reject the null hypothesis.")
else:
    print("We accept the null hypothesis.")
    
# Visualize results using a heatmap
sns.heatmap(iris.groupby("species").corr(), annot=True, cmap="YlGnBu")
# Out:
# Null hypothesis: The mean petal length is equal across all three species of iris (setosa, versicolor, and virginica).
# Alternative hypothesis: The mean petal length differs across at least one of the three species of iris.
# F-value: 1180.161182252981
# P-value: 2.8567766109615584e-91
# We reject the null hypothesis.
# <Axes: ylabel='species-None'>

# %%
import pandas as pd
import seaborn as sns
from statsmodels.formula.api import ols
from statsmodels.stats.anova import anova_lm

# Load iris.csv dataset from Github
iris = sns.load_dataset("iris")

# Replace NaN values with 0
iris.fillna(0, inplace=True)

# Define null and alternative hypotheses
null_hypothesis = "There is no significant interaction between the species and the petal width in determining petal length."
alt_hypothesis = "There is a significant interaction between the species and the petal width in determining petal length."

# Fit the model with the formula
model = ols('petal_length ~ species + petal_width + species:petal_width', data=iris).fit()

# Perform two-way ANOVA test
anova_table = anova_lm(model, typ=2)

# Print results
print("Null hypothesis:", null_hypothesis)
print("Alternative hypothesis:", alt_hypothesis)
print(anova_table)

# Define significance level
alpha = 0.05

# Determine whether to accept or reject null hypothesis
if anova_table['PR(>F)'][2] < alpha:
    print("We reject the null hypothesis.")
else:
    print("We accept the null hypothesis.")
    
# Visualize results using a heatmap
sns.heatmap(iris.groupby(["species", "petal_width"]).mean()["petal_length"].unstack(), annot=True, cmap="YlGnBu")
# Out:
# Null hypothesis: There is no significant interaction between the species and the petal width in determining petal length.
# Alternative hypothesis: There is a significant interaction between the species and the petal width in determining petal length.
#                         sum_sq     df          F        PR(>F)
# species              13.011309    2.0  49.789099  3.665504e-17
# petal_width           6.389156    1.0  48.897510  9.337809e-11
# species:petal_width   2.017795    2.0   7.721298  6.525078e-04
# Residual             18.815649  144.0        NaN           NaN
# We reject the null hypothesis.
# <Axes: xlabel='petal_width', ylabel='species'>

# %%
import pandas as pd
import seaborn as sns
from statsmodels.formula.api import ols
from statsmodels.stats.anova import anova_lm
import matplotlib.pyplot as plt

# Load iris.csv dataset from Github
iris = sns.load_dataset("iris")

# Replace NaN values with 0
iris.fillna(0, inplace=True)

# Define null and alternative hypotheses
null_hypothesis = "There is no significant interaction between the species and the petal width in determining petal length."
alt_hypothesis = "There is a significant interaction between the species and the petal width in determining petal length."

# Fit the model with the formula
model = ols('petal_length ~ species + petal_width + species:petal_width', data=iris).fit()

# Perform two-way ANOVA test
anova_table = anova_lm(model, typ=2)

# Print results
print("Null hypothesis:", null_hypothesis)
print("Alternative hypothesis:", alt_hypothesis)
print(anova_table)

# Define significance level
alpha = 0.05

# Determine whether to accept or reject null hypothesis
if anova_table['PR(>F)'][2] < alpha:
    print("We reject the null hypothesis.")
else:
    print("We accept the null hypothesis.")
    
# Visualize results using a heatmap
plt.figure(figsize=(10,8)) # set the size of the plot
sns.heatmap(iris.groupby(["species", "petal_width"]).mean()["petal_length"].unstack(), annot=True, cmap="YlGnBu")
plt.show()
# Out:
# Null hypothesis: There is no significant interaction between the species and the petal width in determining petal length.
# Alternative hypothesis: There is a significant interaction between the species and the petal width in determining petal length.
#                         sum_sq     df          F        PR(>F)
# species              13.011309    2.0  49.789099  3.665504e-17
# petal_width           6.389156    1.0  48.897510  9.337809e-11
# species:petal_width   2.017795    2.0   7.721298  6.525078e-04
# Residual             18.815649  144.0        NaN           NaN
# We reject the null hypothesis.
